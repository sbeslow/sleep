# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
sleep_logs = pd.read_csv('data/sleep_list.csv')
sleep_logs = sleep_logs.drop_duplicates(subset='dateOfSleep', keep='last')
sleep_logs = sleep_logs.set_index('dateOfSleep').drop('Unnamed: 0', 1)
sleep_logs.head()
# Out:
#              awakeCount  awakeDuration  awakeningsCount  duration  efficiency  \
# dateOfSleep
# 2016-12-11            1              2                4  29640000          99
# 2016-12-10            0              0                8  26040000          95
# 2016-12-09            0              0                7  23640000          98
# 2016-12-08            1              1                8  25260000          97
# 2016-12-07            0              0                5  30360000          98
#
#             isMainSleep        logId  minutesAfterWakeup  minutesAsleep  \
# dateOfSleep
# 2016-12-11         True  13198145736                   0            489
# 2016-12-10         True  13190828758                   0            413
# 2016-12-09         True  13187958640                   0            385
# 2016-12-08         True  13178275354                   0            407
# 2016-12-07         True  13169494070                   0            496
#
# ...

# %%
import traceback
date_iter = datetime.now().date()
end_date = pd.to_datetime('1/1/2016').date()
while date_iter > end_date:
    try:
        a = sleep_logs.loc[str(date_iter)]
    except:
        # traceback.print_exc()
        print(str(date_iter))
    date_iter -= timedelta(days=1)
# Out:
# 2016-12-12
# 2016-09-02
# 2016-09-01
# 2016-08-31
# 2016-08-30
# 2016-08-29
# 2016-08-28
# 2016-08-27
# 2016-08-26
# 2016-08-25
# 2016-08-24
# 2016-08-10
# 2016-06-30

# %% [markdown]
# FitBit has no data from 8/24/2016 through 9/2/2016
#
# FitBit has no data for 6/30/2016

# %%
type(sleep_logs.index.values[0])
# Out:
# str

# %%
end_date = pd.to_datetime('9/1/2016').date()
b = str(end_date)
a = sleep_logs.loc(str(end_date))
b
# Out:
# '2016-09-01'

# %%
a = sleep_logs.l('2016-09-01')
a.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-8588ebe237be> in <module>()
#       1 a = sleep_logs.loc('2016-09-01')
# ----> 2 a.head()
#
# AttributeError: '_LocIndexer' object has no attribute 'head'

# %%
sleep_logs.loc['2016-12-11']
# Out:
# awakeCount                                   1
# awakeDuration                                2
# awakeningsCount                              4
# duration                              29640000
# efficiency                                  99
# isMainSleep                               True
# logId                              13198145736
# minutesAfterWakeup                           0
# minutesAsleep                              489
# minutesAwake                                 5
# minutesToFallAsleep                          0
# restlessCount                                3
# restlessDuration                             3
# startTime              2016-12-10T22:35:30.000
# timeInBed                                  494
# Name: 2016-12-11, dtype: object

# %%
sleep_logs = sleep_logs.sort_index(ascending=False)
sleep_logs.head()
# Out:
#              awakeCount  awakeDuration  awakeningsCount  duration  efficiency  \
# dateOfSleep
# 2016-12-11            1              2                4  29640000          99
# 2016-12-10            0              0                8  26040000          95
# 2016-12-09            0              0                7  23640000          98
# 2016-12-08            1              1                8  25260000          97
# 2016-12-07            0              0                5  30360000          98
#
#             isMainSleep        logId  minutesAfterWakeup  minutesAsleep  \
# dateOfSleep
# 2016-12-11         True  13198145736                   0            489
# 2016-12-10         True  13190828758                   0            413
# 2016-12-09         True  13187958640                   0            385
# 2016-12-08         True  13178275354                   0            407
# 2016-12-07         True  13169494070                   0            496
#
# ...

# %%
sleep_logs.tail()
# Out:
#              awakeCount  awakeDuration  awakeningsCount  duration  efficiency  \
# dateOfSleep
# 2015-12-16            1              4               11  29640000          96
# 2015-12-15            3              9               10  22860000          93
# 2015-12-14            1              1                8  31440000          98
# 2015-12-12            1              1               14  26460000          95
# 2015-12-11            0              0               12  28920000          95
#
#             isMainSleep        logId  minutesAfterWakeup  minutesAsleep  \
# dateOfSleep
# 2015-12-16         True  10355428583                   0            472
# 2015-12-15         True  10346392740                   0            354
# 2015-12-14         True  10338871982                   0            512
# 2015-12-12         True  10329406735                   0            420
# 2015-12-11         True  10323887643                   0            460
#
# ...

# %%
sleep_logs.to_csv('data/sleep_list.csv')
